# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Product":["Laptop","Mobile","Laptop","Tablet","Mobile","Tablet","Laptop"],
    "Sales":[50000,30000,40000,20000,25000,15000,35000]
}

df = pd.DataFrame(data)
df
# Out:
#   Product  Sales
# 0  Laptop  50000
# 1  Mobile  30000
# 2  Laptop  40000
# 3  Tablet  20000
# 4  Mobile  25000
# 5  Tablet  15000
# 6  Laptop  35000

# %%
sales_summary = df.groupby("Product")["Sales"].sum()
print(sales_summary)
# Out:
# Product
# Laptop    125000
# Mobile     55000
# Tablet     35000
# Name: Sales, dtype: int64

# %%
sales_summary.plot(kind="bar")
plt.title("Total Sales by Product")
plt.show()
